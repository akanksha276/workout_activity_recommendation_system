# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
columns = ['userId','gender','sport','id','longitude','latitude','altitude','timestamp','time_elapsed',
           'heart_rate','derived_speed','distance','tar_heart_rate','tar_derived_speed','since_begin','since_last']

# %% [markdown]
# thirty million eight hundred ninety-seven thousand six hundred rows

# %%
final_df.describe()
# Out:
#              userId            id     longitude      latitude      altitude  \
# count  3.089760e+07  3.089760e+07  3.089760e+07  3.089760e+07  3.089760e+07
# mean   4.581047e+06  3.645500e+08  1.165609e+01  4.277707e+01 -9.621740e-02
# std    3.877977e+06  1.598918e+08  4.954340e+01  2.009642e+01  4.635084e+00
# min    6.900000e+01  2.579360e+05 -1.600009e+02 -5.149342e+01 -5.050843e+02
# 25%    1.520156e+06  2.599629e+08 -3.608460e-01  3.947421e+01 -2.163103e+00
# 50%    3.381703e+06  3.597589e+08  1.089222e+01  5.016756e+01 -1.544809e+00
# 75%    7.038373e+06  4.859358e+08  1.983358e+01  5.561294e+01  1.674268e-01
# max    1.548142e+07  6.740080e+08  1.773666e+02  6.968066e+01  1.422245e+02
#
#           timestamp  time_elapsed    heart_rate  derived_speed      distance  \
# count  3.089760e+07  3.089760e+07  3.089760e+07   3.089760e+07  3.089760e+07
# mean   1.398707e+09 -5.592344e-02 -3.683366e-01  -3.843169e-01  4.250600e+00
# ...

# %%
final_df['userId'].value_counts().describe()
# Out:
# count      1038.000000
# mean      29766.473988
# std       35552.516648
# min         300.000000
# 25%        5700.000000
# 50%       17100.000000
# 75%       40950.000000
# max      275100.000000
# Name: userId, dtype: float64

# %%
final_df['userId'].value_counts()[:50].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
column_data = final_df['userId'].value_counts()
plt.hist(column_data, bins=20,  rwidth=0.8)
# Customize the x-axis labels to display full numbers
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=90)
plt.ylabel('value count of user id')
plt.show()

# %%
final_df['altitude'].describe()
# Out:
# count    3.089760e+07
# mean    -9.621740e-02
# std      4.635084e+00
# min     -5.050843e+02
# 25%     -2.163103e+00
# 50%     -1.544809e+00
# 75%      1.674268e-01
# max      1.422245e+02
# Name: altitude, dtype: float64

# %%
prep_df = final_df.copy()

# %%
prep_df = pd.concat([prep_df,pd.get_dummies(final_df['gender'], prefix='gender')],axis=1)
prep_df.drop(['gender'],axis=1, inplace=True)

# %%
prep_df

# %%
final_df.to_csv('final_processed.csv') # THIS WILL HANG YOUR COMPUTER DO NOT DO THIS

# %%
df_csv = pd.read_csv('final_processed.csv')

# %%
df_csv['sport'].value_counts()
# Out:
# bike                       14547900
# run                        11760300
# mountain bike               2313300
# bike (transport)             970200
# indoor cycling               396000
# cross-country skiing         189000
# walk                         185400
# orienteering                 165900
# core stability training       77400
# hiking                        57900
# fitness walking               55800
# roller skiing                 47400
# skate                         37200
# kayaking                      18000
# circuit training              15900
# rowing                        13800
# weight training                9300
# downhill skiing                7200
# soccer                         6300
# snowshoeing                    4500
# golf                           3300
# horseback riding               2100
# treadmill running              1500
# climbing                       1500
# badminton                      1500
# tennis                         1500
# ...

# %%
df_csv['tar_heart_rate'].describe()
# Out:
# count    3.089760e+07
# mean     1.369686e+02
# std      2.173212e+01
# min      5.000000e+01
# 25%      1.239873e+02
# 50%      1.390781e+02
# 75%      1.520038e+02
# max      2.000000e+02
# Name: tar_heart_rate, dtype: float64

# %%
unique_sports = df_csv['sport'].unique()

# %%
unique_sports
# Out:
# array(['bike', 'run', 'bike (transport)', 'mountain bike', 'rowing',
#        'tennis', 'kayaking', 'indoor cycling', 'cross-country skiing',
#        'core stability training', 'hiking', 'orienteering', 'soccer',
#        'walk', 'basketball', 'circuit training', 'weight training',
#        'skate', 'snowshoeing', 'snowboarding', 'fitness walking',
#        'treadmill running', 'elliptical', 'gymnastics', 'roller skiing',
#        'horseback riding', 'downhill skiing', 'aerobics', 'golf',
#        'badminton', 'swimming', 'table tennis', 'sailing', 'kite surfing',
#        'climbing', 'squash', 'stair climing', 'martial arts', 'rugby'],
#       dtype=object)

# %%
sport_info = df_csv.groupby(['sport']).mean()

# %%
sport_info_df = pd.DataFrame(sport_info)

# %%
gender_counts = df_csv['gender'].value_counts()

# %%
gender_sport_counts = df_csv.groupby([ "sport"])["gender"].value_counts()

# %%
gender_sport_counts
# Out:
# sport            gender
# aerobics         male            300
# badminton        male           1500
# basketball       male           1200
# bike             male       13809300
#                  female       597300
#                               ...
# walk             male         135900
#                  female        49500
# weight training  male           6900
#                  female         2100
#                  unknown         300
# Name: gender, Length: 66, dtype: int64

# %%
d = gender_sport_counts.to_dict()

# %%
d.items()
# Out:
# dict_items([(('aerobics', 'male'), 300), (('badminton', 'male'), 1500), (('basketball', 'male'), 1200), (('bike', 'male'), 13809300), (('bike', 'female'), 597300), (('bike', 'unknown'), 141300), (('bike (transport)', 'male'), 951300), (('bike (transport)', 'female'), 18900), (('circuit training', 'male'), 13500), (('circuit training', 'female'), 2400), (('climbing', 'male'), 1500), (('core stability training', 'male'), 67800), (('core stability training', 'female'), 8400), (('core stability training', 'unknown'), 1200), (('cross-country skiing', 'male'), 149700), (('cross-country skiing', 'female'), 39300), (('downhill skiing', 'male'), 7200), (('elliptical', 'male'), 600), (('fitness walking', 'female'), 30300), (('fitness walking', 'male'), 25200), (('fitness walking', 'unknown'), 300), (('golf', 'male'), 3300), (('gymnastics', 'male'), 300), (('hiking', 'male'), 49800), (('hiking', 'female'), 8100), (('horseback riding', 'male'), 1200), (('horseback riding', 'female'), 900), (('in
# ...

# %%
gender = ("male", "female", "unknown")

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, gender_count in d.items():
    p = ax.bar(gender, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

plt.show()


# data from https://allisonhorst.github.io/palmerpenguins/

species = (
    "Adelie\n $\\mu=$3700.66g",
    "Chinstrap\n $\\mu=$3733.09g",
    "Gentoo\n $\\mu=5076.02g$",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, weight_count in weight_counts.items():
    p = ax.bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

ax.set_title("Number of penguins with above average body mass")
ax.legend(loc="upper right")

plt.show()

# %%
 df_csv['tar_derived_speed'].describe()
# Out:
# count    3.089760e+07
# mean     1.683976e+01
# std      4.908565e+02
# min     -1.917850e+04
# 25%      1.007249e+01
# 50%      1.411164e+01
# 75%      2.636218e+01
# max      4.764413e+05
# Name: tar_derived_speed, dtype: float64

# %%
 df_csv['derived_speed'].describe()
# Out:
# count    3.089760e+07
# mean    -3.843169e-01
# std      1.952560e+02
# min     -7.636031e+03
# 25%     -3.076244e+00
# 50%     -1.469524e+00
# 75%      3.403575e+00
# max      1.895148e+05
# Name: derived_speed, dtype: float64

# %%
fig, ax = plt.subplots()

ax.bar(unique_sports, df_csv['derived_speed'].min())
fig.set_size_inches(20,5)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Time')
plt.title('Time Elapsed Mean Per Sport')
plt.show()

# %%
df_csv['tar_derived_speed'].describe()
# Out:
# count    3.089760e+07
# mean     1.683976e+01
# std      4.908565e+02
# min     -1.917850e+04
# 25%      1.007249e+01
# 50%      1.411164e+01
# 75%      2.636218e+01
# max      4.764413e+05
# Name: tar_derived_speed, dtype: float64

# %%
fig, ax = plt.subplots()

ax.bar(unique_sports, df_csv['sport'].value_counts())
fig.set_size_inches(20,5)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Value Counts')
plt.title('Value Conts Per Sport')
plt.show()

# %%
sport_info_df = sport_info_df.sort_values('tar_heart_rate')

# %%
sport_info_df['tar_heart_rate']
# Out:
# sport
# table tennis                88.314442
# golf                        89.969173
# gymnastics                  90.421192
# downhill skiing             95.498965
# snowboarding                99.895385
# stair climing              101.655458
# walk                       102.647730
# martial arts               108.279035
# hiking                     112.958978
# fitness walking            114.646010
# weight training            115.120318
# kayaking                   119.278584
# basketball                 122.587557
# snowshoeing                124.687099
# circuit training           124.945787
# bike (transport)           125.097294
# skate                      125.560117
# indoor cycling             130.427261
# tennis                     130.957516
# roller skiing              131.273342
# rowing                     131.604939
# core stability training    132.433325
# bike                       132.433776
# mountain bike              135.808573
# ...

# %%
fig, ax = plt.subplots()

ax.bar(unique_sports, sport_info_df['tar_heart_rate'])
fig.set_size_inches(20,5)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Target Heart Rate')
plt.title('Mean Target Heart Rate Per Sport')
plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(unique_sports, sport_info_df['tar_heart_rate'])
fig.set_size_inches(20,5)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Target Heart Rate')
plt.title('Min Target Heart Rate Per Sport')
plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(unique_sports, sport_info_df['tar_heart_rate'])
fig.set_size_inches(20,5)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Target Heart Rate')
plt.title('Max Target Heart Rate Per Sport')
plt.show()
